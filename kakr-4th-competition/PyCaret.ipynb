# %% [markdown]
# # PyCaret 이용한 AutoML 기반 코드
#
# [캐글 노트북](https://www.kaggle.com/qkrwlsdn96/automl-by-pycaret-base-pb-score-0-87669)

# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd
train = pd.read_csv('Data/train.csv')
test = pd.read_csv('Data/test.csv')

# %% [markdown]
# ## 데이터 구조 확인

# %%
print(train.shape)
print(test.shape)
# Out:
# (26049, 16)
# (6512, 15)

# %%
train.head(3)
# Out:
#    id  age workclass  fnlwgt     education  education_num      marital_status  \
# 0   0   40   Private  168538       HS-grad              9  Married-civ-spouse
# 1   1   17   Private  101626           9th              5       Never-married
# 2   2   18   Private  353358  Some-college             10       Never-married
#
#           occupation relationship   race   sex  capital_gain  capital_loss  \
# 0              Sales      Husband  White  Male             0             0
# 1  Machine-op-inspct    Own-child  White  Male             0             0
# 2      Other-service    Own-child  White  Male             0             0
#
#    hours_per_week native_country income
# 0              60  United-States   >50K
# 1              20  United-States  <=50K
# 2              16  United-States  <=50K

# %% [markdown]
# ## 함수 불러오기

# %%
import pycaret.classification as pyclf

# %% [markdown]
# ## 실험 환경 구축
#
# * PyCaret은 모델 학습 전 실험 환경 구축 필요 via `setup` 함수
# * `setup` 단계에서는 PyCaret이 자동으로 컬럼 형태를 인식

# %%
# income 컬럼이 예측 대상이므로 target 인자에 명시
clf = pyclf.setup(data=train, target='income')
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row0_col1" class="data row0 col1" >6743</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row2_col1" class="data row2 col1" ><=50K: 0, >50K: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row3_col1" class="data row3 col1" >(26049, 16)</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row5_col1" class="data row5 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row6_col1" class="data row6 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row10_col1" class="data row10 col1" >(26049, 16)</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row11_col1" class="data row11 col1" >(18234, 122)</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row12_col1" class="data row12 col1" >(7815, 122)</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_5aaa99ae_0efd_11eb_b12e_0cdd242c0aa6row18_col1" class="data row18 col1" >None</td>

# %% [markdown]
# ## 모델 학습 및 비교
#
# * `compared_models` 함수를 통해 15개의 기본 모델을 학습하고 성능 비교
# * 대회 지표인 F1 기준으로 3개 모델 저장

# %%
best_3 = pyclf.compare_models(sort='F1', n_select=3)
# Out:
# <style  type="text/css" >
#     #T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6 th {
#           text-align: left;
#     }#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row0_col0,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row0_col1,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row0_col2,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row0_col3,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row0_col4,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row1_col0,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row1_col1,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row1_col2,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row1_col3,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row1_col4,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row1_col5,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row1_col6,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row1_col7,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row2_col0,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row2_col3,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row2_col4,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row2_col5,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row2_col6,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row2_col7,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row3_col0,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row3_col1,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row3_col2,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row3_col3,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row3_col4,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row3_col5,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row3_col6,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row3_col7,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row4_col0,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row4_col1,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row4_col2,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row4_col3,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row4_col5,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row4_col6,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row4_col7,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row5_col0,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row5_col1,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row5_col2,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row5_col3,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row5_col4,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row5_col5,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row5_col6,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row5_col7,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row6_col0,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row6_col1,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row6_col2,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row6_col3,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row6_col4,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row6_col5,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row6_col6,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row6_col7,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row7_col0,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row7_col1,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row7_col2,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row7_col3,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row7_col4,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row7_col5,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row7_col6,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row7_col7,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row8_col0,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row8_col1,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row8_col2,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row8_col3,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row8_col4,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row8_col5,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row8_col6,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row8_col7,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row9_col0,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row9_col1,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row9_col2,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row9_col3,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row9_col4,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row9_col5,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row9_col6,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row9_col7,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row10_col0,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row10_col1,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row10_col2,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row10_col4,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row10_col5,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row10_col6,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row10_col7,#T_f36d017c_0efd_11 ...
#             text-align:  left;
#         }#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row0_col5,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row0_col6,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row0_col7,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row2_col1,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row2_col2,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row4_col4,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row10_col3{
#             background-color:  yellow;
#             text-align:  left;
#         }#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row0_col8,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row1_col8,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row2_col8,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row3_col8,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row4_col8,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row5_col8,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row6_col8,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row7_col8,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row8_col8,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row9_col8,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row10_col8,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row11_col8,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row12_col8,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row13_col8,#T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row14_col8{
#             background-color:  lightgrey;
#             text-align:  left;
#         }</style><table id="T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_f36d017c_0efd_11eb_b12e_0cdd242c0aa6row0_col1" class="data row0 col1" >0.8

# %% [markdown]
# ## 모델 앙상블

# %%
best_3
# Out:
# [LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                 importance_type='split', learning_rate=0.1, max_depth=-1,
#                 min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                 n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                 random_state=6743, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                 subsample=1.0, subsample_for_bin=200000, subsample_freq=0),
#  XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#                importance_type='gain', interaction_constraints='',
#                learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#                min_child_weight=1, missing=nan, monotone_constraints='()',
#                n_estimators=100, n_jobs=-1, num_parallel_tree=1,
#                objective='binary:logistic', random_state=6743, reg_alpha=0,
#                reg_lambda=1, scale_pos_weight=1, subsample=1,
#                tree_method='exact', validate_parameters=1, verbosity=0),
#  <catboost.core.CatBoostClassifier at 0x7f37905bdb10>]

# %%
blended = pyclf.blend_models(estimator_list=best_3, fold=5, method='soft')
# Out:
# <style  type="text/css" >
# #T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row5_col0,#T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row5_col1,#T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row5_col2,#T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row5_col3,#T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row5_col4,#T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row5_col5,#T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row5_col6{
#             background:  yellow;
#         }</style><table id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row0_col0" class="data row0 col0" >0.8687</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row0_col1" class="data row0 col1" >0.9269</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row0_col2" class="data row0 col2" >0.6553</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row0_col3" class="data row0 col3" >0.7676</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row0_col4" class="data row0 col4" >0.7070</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row0_col5" class="data row0 col5" >0.6231</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row0_col6" class="data row0 col6" >0.6263</td>
#             </tr>
#             <tr>
#                         <th id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row1_col0" class="data row1 col0" >0.8755</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row1_col1" class="data row1 col1" >0.9303</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row1_col2" class="data row1 col2" >0.6659</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row1_col3" class="data row1 col3" >0.7871</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row1_col4" class="data row1 col4" >0.7215</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row1_col5" class="data row1 col5" >0.6420</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row1_col6" class="data row1 col6" >0.6458</td>
#             </tr>
#             <tr>
#                         <th id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row2_col0" class="data row2 col0" >0.8684</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row2_col1" class="data row2 col1" >0.9281</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row2_col2" class="data row2 col2" >0.6591</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row2_col3" class="data row2 col3" >0.7648</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row2_col4" class="data row2 col4" >0.7080</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row2_col5" class="data row2 col5" >0.6237</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row2_col6" class="data row2 col6" >0.6265</td>
#             </tr>
#             <tr>
#                         <th id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row3_col0" class="data row3 col0" >0.8656</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row3_col1" class="data row3 col1" >0.9283</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row3_col2" class="data row3 col2" >0.6308</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row3_col3" class="data row3 col3" >0.7725</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row3_col4" class="data row3 col4" >0.6945</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row3_col5" class="data row3 col5" >0.6095</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row3_col6" class="data row3 col6" >0.6147</td>
#             </tr>
#             <tr>
#                         <th id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row4_col0" class="data row4 col0" >0.8725</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row4_col1" class="data row4 col1" >0.9269</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row4_col2" class="data row4 col2" >0.6485</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row4_col3" class="data row4 col3" >0.7868</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row4_col4" class="data row4 col4" >0.7110</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row4_col5" class="data row4 col5" >0.6301</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row4_col6" class="data row4 col6" >0.6350</td>
#             </tr>
#             <tr>
#                         <th id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6level0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row5_col0" class="data row5 col0" >0.8701</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row5_col1" class="data row5 col1" >0.9281</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row5_col2" class="data row5 col2" >0.6519</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row5_col3" class="data row5 col3" >0.7758</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row5_col4" class="data row5 col4" >0.7084</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row5_col5" class="data row5 col5" >0.6257</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row5_col6" class="data row5 col6" >0.6297</td>
#             </tr>
#             <tr>
#                         <th id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6level0_row6" class="row_heading level0 row6" >SD</th>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row6_col0" class="data row6 col0" >0.0035</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row6_col1" class="data row6 col1" >0.0012</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row6_col2" class="data row6 col2" >0.0120</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row6_col3" class="data row6 col3" >0.0095</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row6_col4" class="data row6 col4" >0.0086</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row6_col5" class="data row6 col5" >0.0106</td>
#                         <td id="T_1b1098f6_0efe_11eb_b12e_0cdd242c0aa6row6_col6" class="data row6 col6" >0.0103</td>
#             </tr>
#     </tbody></table>

# %%
blended
# Out:
# VotingClassifier(estimators=[('Light Gradient Boosting Machine_0',
#                               LGBMClassifier(boosting_type='gbdt',
#                                              class_weight=None,
#                                              colsample_bytree=1.0,
#                                              importance_type='split',
#                                              learning_rate=0.1, max_depth=-1,
#                                              min_child_samples=20,
#                                              min_child_weight=0.001,
#                                              min_split_gain=0.0,
#                                              n_estimators=100, n_jobs=-1,
#                                              num_leaves=31, objective=None,
#                                              random_state=6743, reg_alpha=0.0,
#                                              reg_la...
#                                             n_estimators=100, n_jobs=-1,
#                                             num_parallel_tree=1,
#                                             objective='binary:logistic',
#                                             random_state=6743, reg_alpha=0,
#                                             reg_lambda=1, scale_pos_weight=1,
#                                             subsample=1, tree_method='exact',
#                                             validate_parameters=1,
#                                             verbosity=0)),
#                              ('Cat Boost Classifier_2',
#                               <catboost.core.CatBoostClassifier object at 0x7f37905bdb10>)],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None)

# %% [markdown]
# ## 모델 예측

# %%
pred_holdout = pyclf.predict_model(blended)
# Out:
#                Model  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0  Voting Classifier    0.8686  0.9261  0.6464  0.7736  0.7043  0.6207  0.6248

# %% [markdown]
# ## 전체 데이터에 대한 재학습
#
# * 현재까지의 실험은 train 데이터를 train/valid 로 나눠 실험한 것
# * 최적의 성능을 위해 전체 데이터에 재학습

# %%
final_model = pyclf.finalize_model(blended)

# %%
final_model
# Out:
# VotingClassifier(estimators=[('Light Gradient Boosting Machine_0',
#                               LGBMClassifier(boosting_type='gbdt',
#                                              class_weight=None,
#                                              colsample_bytree=1.0,
#                                              importance_type='split',
#                                              learning_rate=0.1, max_depth=-1,
#                                              min_child_samples=20,
#                                              min_child_weight=0.001,
#                                              min_split_gain=0.0,
#                                              n_estimators=100, n_jobs=-1,
#                                              num_leaves=31, objective=None,
#                                              random_state=6743, reg_alpha=0.0,
#                                              reg_la...
#                                             n_estimators=100, n_jobs=-1,
#                                             num_parallel_tree=1,
#                                             objective='binary:logistic',
#                                             random_state=6743, reg_alpha=0,
#                                             reg_lambda=1, scale_pos_weight=1,
#                                             subsample=1, tree_method='exact',
#                                             validate_parameters=1,
#                                             verbosity=0)),
#                              ('Cat Boost Classifier_2',
#                               <catboost.core.CatBoostClassifier object at 0x7f37905f3d50>)],
#                  flatten_transform=True, n_jobs=-1, verbose=False,
#                  voting='soft', weights=None)

# %% [markdown]
# ## Test set 예측

# %%
preds = pyclf.predict_model(final_model, data=test)
preds
# Out:
#         id  age     workclass  fnlwgt     education  education_num  \
# 0        0   28       Private   67661  Some-college             10
# 1        1   40  Self-emp-inc   37869       HS-grad              9
# 2        2   20       Private  109952  Some-college             10
# 3        3   40       Private  114537     Assoc-voc             11
# 4        4   37       Private   51264     Doctorate             16
# ...    ...  ...           ...     ...           ...            ...
# 6507  6507   35       Private   61343     Bachelors             13
# 6508  6508   41  Self-emp-inc   32185     Bachelors             13
# 6509  6509   39       Private  409189       5th-6th              3
# 6510  6510   35       Private  180342       HS-grad              9
# 6511  6511   28       Private  156819       HS-grad              9
#
#           marital_status         occupation    relationship   race     sex  \
# 0          Never-married       Adm-clerical  Other-relative  White  Female
# 1     Married-civ-spouse    Exec-managerial         Husband  White    Male
# 2          Never-married  Handlers-cleaners       Own-child  White    Male
# 3     Married-civ-spouse    Exec-managerial         Husband  White    Male
# 4     Married-civ-spouse     Prof-specialty         Husband  White    Male
# ...                  ...                ...             ...    ...     ...
# 6507  Married-civ-spouse              Sales         Husband  White    Male
# 6508  Married-civ-spouse       Tech-support         Husband  White    Male
# 6509  Married-civ-spouse      Other-service         Husband  White    Male
# 6510  Married-civ-spouse       Craft-repair         Husband  White    Male
# 6511            Divorced  Handlers-cleaners       Unmarried  White  Female
#
#       capital_gain  capital_loss  hours_per_week native_country  Label   Score
# 0                0             0              40  United-States  <=50K  0.0039
# 1                0             0              50  United-States   >50K  0.5363
# 2                0             0              25  United-States  <=50K  0.0002
# 3                0             0              50  United-States   >50K  0.6956
# 4                0             0              99         France  <=50K  0.3577
# ...            ...           ...             ...            ...    ...     ...
# 6507             0             0              40  United-States   >50K  0.5166
# 6508             0             0              40  United-States   >50K  0.6123
# 6509             0             0              40         Mexico  <=50K  0.0268
# 6510             0             0              40  United-States  <=50K  0.2123
# 6511             0             0              36  United-States  <=50K  0.0052
#
# [6512 rows x 17 columns]

# %%
submission = preds[['id','Score']]
submission.head(2)
# Out:
#    id   Score
# 0   0  0.0039
# 1   1  0.5363

# %%
submission['prediction'] = (submission['Score'] >= 0.5).astype(int)
submission.head(2)
# Out:
#    id   Score  prediction
# 0   0  0.0039           0
# 1   1  0.5363           1

# %%
submission_fin = submission[['id','prediction']]
submission_fin.head(2)
# Out:
#    id  prediction
# 0   0           0
# 1   1           1

# %%
submission_fin.to_csv('submissions/submission_pycaret.csv', index=False)

# %%
# !kaggle competitions submit -c kakr-4th-competition -f submissions/submission_pycaret.csv -m "Message"
# Out:
# 100%|██████████████████████████████████████| 43.4k/43.4k [00:04<00:00, 10.0kB/s]
# Successfully submitted to [T-Academy X KaKr] 성인 인구조사 소득 예측 대회
